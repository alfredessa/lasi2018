# %%
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
# %matplotlib inline
print sys.version
print "Pandas", pd.__version__
print "Numpy", np.__version__
print "Seaborn", sns.__version__
# Out:
# 2.7.14 |Anaconda, Inc.| (default, Oct  5 2017, 02:28:52)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# Pandas 0.20.3
# Numpy 1.13.3
# Seaborn 0.8.0

# %%
ls
# Out:
# LifeExpectancy.ipynb  PythonBasics.ipynb    data/
# NumPy.ipynb           Titanic.ipynb         titanic3.xls
# Numpy2.ipynb          Untitled.ipynb

# %%
t = sns.load_dataset('titanic')

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null category
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
sns.distplot(titanic.age.dropna())

# %%
sns.distplot(titanic.age.dropna())

# %%
sns.factorplot(x="sex", y="survived", data=titanic)

# %%
sns.factorplot(x="sex", y="survived", hue='pclass',data=titanic)

# %%
sns.factorplot(x="embarked", y="survived",data=titanic)

# %%
sns.factorplot(x="sex", y="survived", hue="embarked", data=titanic)
